# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
ds = pd.read_csv('../data/convusersec/twconvrsu_csv_v2i_60k/train.csv')
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59974 entries, 0 to 59973
# Data columns (total 3 columns):
# Context      59974 non-null object
# Utterance    59923 non-null object
# Label        59974 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 1.4+ MB

# %%
ds.Context.str.len().plot.hist(bins=100)
plt.yscale('log')

# %%
ds.Utterance.str.len().plot.hist(bins=100)
plt.yscale('log')
